# %% [markdown]
# # Multiclass Classification Example
#
# In this notebook, we will go over how to mimic a scikit learn model that performs multiclass classification using the `aisquared` library.

# %%
# import all required packages
from aisquared import utils
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
# Load the data and split into training and testing sets
data = load_iris()['data']
labels = load_iris()['target']

x_train, x_test, y_train, y_test = train_test_split(data, labels)

scaler = MinMaxScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Train the scikit-learn classifier
clf = DecisionTreeClassifier(max_depth = 4).fit(x_train, y_train)

# %%
# Create the neural network to train with
nnet = utils.get_model('fc', x_train.shape[-1], np.unique(y_train).shape[0], output_activation = 'softmax', size = 'medium')

# %%
# Use the mimic_model function to train the neural network to replicate the original model's performance
nnet = utils.mimic_model(
clf,
nnet,
x_train,
x_test,
y_test,
'classification',
'mse',
'accuracy',
'adam',
mimic_proba = True
)
# Out:
# Epoch 1/100
# 2023-01-05 14:31:07.367719: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2227 - accuracy: 0.0938Performance measure set to accuracy
# Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2158 - accuracy: 0.4107
# Epoch 2/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2077 - accuracy: 0.5625Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2039 - accuracy: 0.6250
# Epoch 3/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1942 - accuracy: 0.6250Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1861 - accuracy: 0.6607
# Epoch 4/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1780 - accuracy: 0.5938Model performance has not reached pruning threshold for 4 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1653 - accuracy: 0.6607
# Epoch 5/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1361 - accuracy: 0.7812Model performance has not reached pruning threshold for 5 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1450 - accuracy: 0.6607
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1163 - accuracy: 0.7500Model performance has not reached pruning threshold for 6 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1134 - accuracy: 0.6607
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0681 - accuracy: 0.9688Model performance has not reached pruning threshold for 7 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0959 - accuracy: 0.8839
# Epoch 8/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0750 - accuracy: 0.7812Model performance has not reached pruning threshold for 8 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1028 - accuracy: 0.6607
# Epoch 9/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0833 - accuracy: 0.7188Model performance has not reached pruning threshold for 9 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0759 - accuracy: 0.8661
# Epoch 10/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0633 - accuracy: 0.8750Model performance reached 0.92, sparsifying to 5
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0579 - accuracy: 0.9196
# Epoch 11/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0729 - accuracy: 0.7812Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0533 - accuracy: 0.8750
# Epoch 12/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0261 - accuracy: 0.9688Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0515 - accuracy: 0.8839
# Epoch 13/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0666 - accuracy: 0.8438Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0494 - accuracy: 0.8839
# Epoch 14/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0431 - accuracy: 0.9062Model performance reached 0.9, sparsifying to 10
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0443 - accuracy: 0.9018
# Epoch 15/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0315 - accuracy: 0.9062Model performance reached 0.91, sparsifying to 15
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0370 - accuracy: 0.9107
# Epoch 16/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0338 - accuracy: 0.9688Model performance reached 0.96, sparsifying to 20
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0249 - accuracy: 0.9554
# Epoch 17/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0128 - accuracy: 1.0000Model performance reached 0.96, sparsifying to 25
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0192 - accuracy: 0.9554
# Epoch 18/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0101 - accuracy: 1.0000Model performance reached 0.97, sparsifying to 30
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0163 - accuracy: 0.9732
# Epoch 19/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0196 - accuracy: 0.9375Model performance reached 0.96, sparsifying to 35
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0182 - accuracy: 0.9643
# Epoch 20/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0158 - accuracy: 0.9688Model performance reached 0.94, sparsifying to 40
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0185 - accuracy: 0.9375
# Epoch 21/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0160 - accuracy: 0.9688Model performance reached 0.97, sparsifying to 45
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0160 - accuracy: 0.9732
# Epoch 22/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000Model performance reached 0.96, sparsifying to 50
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0149 - accuracy: 0.9643
# Epoch 23/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0181 - accuracy: 0.9688Model performance reached 0.96, sparsifying to 55
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0175 - accuracy: 0.9554
# Epoch 24/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0185 - accuracy: 1.0000Model performance reached 0.97, sparsifying to 60
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0197 - accuracy: 0.9732
# Epoch 25/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0196 - accuracy: 0.9688Model performance reached 0.96, sparsifying to 65
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0206 - accuracy: 0.9643
# Epoch 26/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0311 - accuracy: 0.9688Model performance reached 0.96, sparsifying to 70
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0296 - accuracy: 0.9554
# Epoch 27/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2456 - accuracy: 0.5625Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1888 - accuracy: 0.6429
# Epoch 28/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1062 - accuracy: 0.6875Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0665 - accuracy: 0.8571
# Epoch 29/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1347 - accuracy: 0.6250Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1049 - accuracy: 0.7143
# Epoch 30/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0650 - accuracy: 0.8125Model performance reached 0.92, sparsifying to 75
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0472 - accuracy: 0.9196
# Epoch 31/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1122 - accuracy: 0.5938Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0783 - accuracy: 0.7589
# Epoch 32/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0435 - accuracy: 0.9375Model performance reached 0.95, sparsifying to 80
# 4/4 [==============================] - 0s 14ms/step - loss: 0.0525 - accuracy: 0.9464
# Epoch 33/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3357 - accuracy: 0.4062Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.3593 - accuracy: 0.3304
# Epoch 34/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.3103 - accuracy: 0.3438Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2894 - accuracy: 0.3393
# Epoch 35/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2485 - accuracy: 0.2812Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1989 - accuracy: 0.5089
# Epoch 36/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1511 - accuracy: 0.6875Model performance has not reached pruning threshold for 4 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 0.6696
# Epoch 37/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1266 - accuracy: 0.6875Model performance has not reached pruning threshold for 5 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1219 - accuracy: 0.7321
# Epoch 38/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1088 - accuracy: 0.9375Model performance reached 0.96, sparsifying to 85
# 4/4 [==============================] - 0s 14ms/step - loss: 0.1107 - accuracy: 0.9643
# Epoch 39/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1936 - accuracy: 0.4062Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2158 - accuracy: 0.3304
# Epoch 40/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1961 - accuracy: 0.4062Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2142 - accuracy: 0.3304
# Epoch 41/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2212 - accuracy: 0.3125Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2098 - accuracy: 0.3304
# Epoch 42/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2339 - accuracy: 0.2188Model performance has not reached pruning threshold for 4 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2050 - accuracy: 0.3304
# Epoch 43/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2063 - accuracy: 0.3125Model performance has not reached pruning threshold for 5 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1998 - accuracy: 0.3304
# Epoch 44/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1973 - accuracy: 0.3125Model performance has not reached pruning threshold for 6 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1956 - accuracy: 0.3304
# Epoch 45/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1925 - accuracy: 0.3750Model performance has not reached pruning threshold for 7 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1920 - accuracy: 0.3304
# Epoch 46/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1964 - accuracy: 0.2812Model performance has not reached pruning threshold for 8 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1894 - accuracy: 0.3304
# Epoch 47/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1931 - accuracy: 0.2812Model performance has not reached pruning threshold for 9 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1873 - accuracy: 0.3304
# Epoch 48/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1807 - accuracy: 0.3438Model performance has not reached pruning threshold for 10 epoch(s)
# Model performance has not reached pruning threshold for 10 epochs, reverting to 80 sparsification and beginning early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1850 - accuracy: 0.3304
# Epoch 49/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1108 - accuracy: 0.9375Early stopping performance has not met threshold for 1 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1097 - accuracy: 0.8929
# Epoch 50/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1063 - accuracy: 0.8750Early stopping performance has not met threshold for 2 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0985 - accuracy: 0.9196
# Epoch 51/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0895 - accuracy: 0.9375Early stopping performance has not met threshold for 3 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0868 - accuracy: 0.9464
# Epoch 52/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0963 - accuracy: 0.9062Early stopping performance has not met threshold for 4 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0791 - accuracy: 0.9286
# Epoch 53/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0702 - accuracy: 0.9375Early stopping performance has not met threshold for 5 epochs
# Model performance has not met early stopping criteria. Stopping training
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9286
# 2/2 [==============================] - 0s 1ms/step
# ORIGINAL PERFORMANCE:
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.92      0.96        13
#            2       0.92      1.00      0.96        12
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.97      0.97        38
# weighted avg       0.98      0.97      0.97        38
#
#
#
#
# MIMIC PERFORMANCE:
#
#
# Relative to First Model:
# [[13  0  0]
#  [ 0 10  2]
#  [ 0  1 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       0.91      0.83      0.87        12
#            2       0.86      0.92      0.89        13
#
#     accuracy                           0.92        38
#    macro avg       0.92      0.92      0.92        38
# weighted avg       0.92      0.92      0.92        38
#
#
#
# Relative to Original:
# [[13  0  0]
#  [ 0 11  2]
#  [ 0  0 12]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        13
#            1       1.00      0.85      0.92        13
#            2       0.86      1.00      0.92        12
#
#     accuracy                           0.95        38
#    macro avg       0.95      0.95      0.95        38
# weighted avg       0.95      0.95      0.95        38

# %%
# Get the predictions on test data from the original classifier and the neural network
clf_preds = clf.predict(x_test)
nnet_preds = nnet.predict(x_test).argmax(axis = 1)
# Out:
# 2/2 [==============================] - 0s 1ms/step

# %%
# Present the confusion matrices for both models

print('Performance on test data for original model:')
print(confusion_matrix(y_test, clf_preds))

print('\n\n')

print('Performance on test data for neural network:')
print(confusion_matrix(y_test, nnet_preds))
# Out:
# Performance on test data for original model:
# [[13  0  0]
#  [ 0 12  1]
#  [ 0  0 12]]
#
#
#
# Performance on test data for neural network:
# [[13  0  0]
#  [ 0 11  2]
#  [ 0  0 12]]
