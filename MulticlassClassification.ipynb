# %% [markdown]
# # Multiclass Classification Example
#
# In this notebook, we will go over how to mimic a scikit learn model that performs multiclass classification using the `aisquared` library.

# %%
# import all required packages
from aisquared import utils
from sklearn.tree import DecisionTreeClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# %%
# Load the data and split into training and testing sets
data = load_iris()['data']
labels = load_iris()['target']

x_train, x_test, y_train, y_test = train_test_split(data, labels)

scaler = MinMaxScaler().fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
# Train the scikit-learn classifier
clf = DecisionTreeClassifier(max_depth = 4).fit(x_train, y_train)

# %%
# Create the neural network to train with
nnet = utils.get_model('fc', x_train.shape[-1], np.unique(y_train).shape[0], output_activation = 'softmax', size = 'medium')

# %%
# Use the mimic_model function to train the neural network to replicate the original model's performance
nnet = utils.mimic_model(
clf,
nnet,
x_train,
x_test,
y_test,
'classification',
'mse',
'accuracy',
'adam',
mimic_proba = True
)
# Out:
# Epoch 1/100
# 1/4 [======>.......................] - ETA: 1s - loss: 0.2211 - accuracy: 0.2812Performance measure set to accuracy
# Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2167 - accuracy: 0.5804
# Epoch 2/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2065 - accuracy: 0.6875Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 2ms/step - loss: 0.2013 - accuracy: 0.7054
# Epoch 3/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1896 - accuracy: 0.6250Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1759 - accuracy: 0.7054
# Epoch 4/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1949 - accuracy: 0.5625Model performance has not reached pruning threshold for 4 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1518 - accuracy: 0.7054
# Epoch 5/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1223 - accuracy: 0.7500Model performance has not reached pruning threshold for 5 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1230 - accuracy: 0.7054
# Epoch 6/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0873 - accuracy: 0.7812Model performance has not reached pruning threshold for 6 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0959 - accuracy: 0.7054
# Epoch 7/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0773 - accuracy: 0.8438Model performance has not reached pruning threshold for 7 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0802 - accuracy: 0.8304
# Epoch 8/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0556 - accuracy: 0.9688Model performance has not reached pruning threshold for 8 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0680 - accuracy: 0.8839
# Epoch 9/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0632 - accuracy: 0.9062Model performance has not reached pruning threshold for 9 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0715 - accuracy: 0.8482
# Epoch 10/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0720 - accuracy: 0.8125Model performance reached 0.91, sparsifying to 5
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0523 - accuracy: 0.9107
# Epoch 11/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0448 - accuracy: 0.8750Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0522 - accuracy: 0.8929
# Epoch 12/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0260 - accuracy: 0.9688Model performance reached 0.95, sparsifying to 10
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0398 - accuracy: 0.9464
# Epoch 13/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0449 - accuracy: 0.9375Model performance reached 0.96, sparsifying to 15
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0314 - accuracy: 0.9643
# Epoch 14/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0251 - accuracy: 0.9688Model performance reached 0.96, sparsifying to 20
# 4/4 [==============================] - 0s 16ms/step - loss: 0.0290 - accuracy: 0.9643
# Epoch 15/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0197 - accuracy: 0.9688Model performance reached 0.96, sparsifying to 25
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0269 - accuracy: 0.9643
# Epoch 16/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0344 - accuracy: 0.9062Model performance reached 0.92, sparsifying to 30
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0327 - accuracy: 0.9196
# Epoch 17/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0243 - accuracy: 0.9375Model performance reached 0.93, sparsifying to 35
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0383 - accuracy: 0.9286
# Epoch 18/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0307 - accuracy: 0.9375Model performance reached 0.94, sparsifying to 40
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0318 - accuracy: 0.9375
# Epoch 19/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0167 - accuracy: 0.9688Model performance reached 0.95, sparsifying to 45
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0322 - accuracy: 0.9464
# Epoch 20/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0332 - accuracy: 0.9375Model performance reached 0.95, sparsifying to 50
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0295 - accuracy: 0.9464
# Epoch 21/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0374 - accuracy: 0.9375Model performance reached 0.93, sparsifying to 55
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0396 - accuracy: 0.9286
# Epoch 22/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0346 - accuracy: 0.9375Model performance reached 0.94, sparsifying to 60
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0373 - accuracy: 0.9375
# Epoch 23/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0373 - accuracy: 0.9688Model performance reached 0.96, sparsifying to 65
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0341 - accuracy: 0.9554
# Epoch 24/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1456 - accuracy: 0.5938Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1064 - accuracy: 0.7500
# Epoch 25/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0391 - accuracy: 0.9688Model performance reached 0.95, sparsifying to 70
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0465 - accuracy: 0.9464
# Epoch 26/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1765 - accuracy: 0.6875Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1658 - accuracy: 0.7054
# Epoch 27/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1272 - accuracy: 0.7500Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1530 - accuracy: 0.7054
# Epoch 28/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1569 - accuracy: 0.6562Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1223 - accuracy: 0.7143
# Epoch 29/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0859 - accuracy: 0.7500Model performance has not reached pruning threshold for 4 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.8036
# Epoch 30/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0874 - accuracy: 0.8125Model performance has not reached pruning threshold for 5 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0774 - accuracy: 0.8661
# Epoch 31/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0645 - accuracy: 0.9062Model performance reached 0.93, sparsifying to 75
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0541 - accuracy: 0.9286
# Epoch 32/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1904 - accuracy: 0.5000Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1994 - accuracy: 0.4286
# Epoch 33/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1697 - accuracy: 0.4688Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1225 - accuracy: 0.6339
# Epoch 34/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0965 - accuracy: 0.7812Model performance reached 0.91, sparsifying to 80
# 4/4 [==============================] - 0s 15ms/step - loss: 0.0962 - accuracy: 0.9107
# Epoch 35/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2035 - accuracy: 0.3750Model performance has not reached pruning threshold for 1 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.2074 - accuracy: 0.3571
# Epoch 36/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.2060 - accuracy: 0.3750Model performance has not reached pruning threshold for 2 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1984 - accuracy: 0.3571
# Epoch 37/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1910 - accuracy: 0.3750Model performance has not reached pruning threshold for 3 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1773 - accuracy: 0.4464
# Epoch 38/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1623 - accuracy: 0.6250Model performance has not reached pruning threshold for 4 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1503 - accuracy: 0.6786
# Epoch 39/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1049 - accuracy: 0.8750Model performance has not reached pruning threshold for 5 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1290 - accuracy: 0.7054
# Epoch 40/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1161 - accuracy: 0.7188Model performance has not reached pruning threshold for 6 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1144 - accuracy: 0.7054
# Epoch 41/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0819 - accuracy: 0.8125Model performance has not reached pruning threshold for 7 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1065 - accuracy: 0.7054
# Epoch 42/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1069 - accuracy: 0.6875Model performance has not reached pruning threshold for 8 epoch(s)
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1020 - accuracy: 0.7054
# Epoch 43/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.1045 - accuracy: 0.7188Model performance has not reached pruning threshold for 9 epoch(s)
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.7054
# Epoch 44/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0974 - accuracy: 0.6875Model performance has not reached pruning threshold for 10 epoch(s)
# Model performance has not reached pruning threshold for 10 epochs, reverting to 75 sparsification and beginning early stopping
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0980 - accuracy: 0.7054
# Epoch 45/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0894 - accuracy: 0.8438Model performance improved to 0.94
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0960 - accuracy: 0.9375
# Epoch 46/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0772 - accuracy: 0.9688Early stopping performance has not met threshold for 1 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0862 - accuracy: 0.9464
# Epoch 47/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0708 - accuracy: 0.9688Model performance improved to 0.96
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0752 - accuracy: 0.9643
# Epoch 48/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0637 - accuracy: 0.9688Early stopping performance has not met threshold for 1 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0669 - accuracy: 0.9464
# Epoch 49/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0656 - accuracy: 0.9062Early stopping performance has not met threshold for 2 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0592 - accuracy: 0.9464
# Epoch 50/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0472 - accuracy: 0.9688Early stopping performance has not met threshold for 3 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0506 - accuracy: 0.9643
# Epoch 51/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0417 - accuracy: 0.9688Early stopping performance has not met threshold for 4 epochs
# 4/4 [==============================] - 0s 1ms/step - loss: 0.0443 - accuracy: 0.9643
# Epoch 52/100
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0428 - accuracy: 0.9375Early stopping performance has not met threshold for 5 epochs
# Model performance has not met early stopping criteria. Stopping training
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0388 - accuracy: 0.9643
# 2/2 [==============================] - 0s 930us/step
# ORIGINAL PERFORMANCE:
# [[11  0  0]
#  [ 0 16  1]
#  [ 0  0 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.94      0.97        17
#            2       0.91      1.00      0.95        10
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38
#
#
#
#
# MIMIC PERFORMANCE:
#
#
# Relative to First Model:
# [[11  0  0]
#  [ 0 16  0]
#  [ 0  0 11]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      1.00      1.00        16
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        38
#    macro avg       1.00      1.00      1.00        38
# weighted avg       1.00      1.00      1.00        38
#
#
#
# Relative to Original:
# [[11  0  0]
#  [ 0 16  1]
#  [ 0  0 10]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.94      0.97        17
#            2       0.91      1.00      0.95        10
#
#     accuracy                           0.97        38
#    macro avg       0.97      0.98      0.97        38
# weighted avg       0.98      0.97      0.97        38

# %%
# Get the predictions on test data from the original classifier and the neural network
clf_preds = clf.predict(x_test)
nnet_preds = nnet.predict(x_test).argmax(axis = 1)
# Out:
# 2/2 [==============================] - 0s 843us/step

# %%
# Present the confusion matrices for both models

print('Performance on test data for original model:')
print(confusion_matrix(y_test, clf_preds))

print('\n\n')

print('Performance on test data for neural network:')
print(confusion_matrix(y_test, nnet_preds))
# Out:
# Performance on test data for original model:
# [[11  0  0]
#  [ 0 16  1]
#  [ 0  0 10]]
#
#
#
# Performance on test data for neural network:
# [[11  0  0]
#  [ 0 16  1]
#  [ 0  0 10]]
